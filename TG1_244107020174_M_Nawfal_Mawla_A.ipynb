# %% [markdown]
# <a href="https://colab.research.google.com/github/MNawfal24/MachineLearning/blob/main/TG1_244107020174_M_Nawfal_Mawla_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mne

# %%
# !SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True pip install pyprep scipy wandb pyECG
# !pip install pyprep scipy wandb pyECG
# Out:
# ...
#   Using cached pyprep-0.9.0-py3-none-any.whl.metadata (7.9 kB)
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...
#   Using cached mne-1.13.2-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached ishneholterlib-2017.4.11.tar.gz (7.0 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached wfdb-2.2.1.tar.gz (94 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached pytest_cov-7.1.0-py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached pycrc-0.11.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached nose-1.3.7-py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 999.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 38.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 18.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# PADA CELL 2 SAYA Menggunakan Perintah Yang tertera untuk menginstall PyREP,Scipy,WandDB dan pyECG
#
# Kegunaan :
# 1. PyREP : Library untuk melakukan preprocessing pada data sinyal EEG (membersihkan data dari noise sebelum data dimasukkan ke dalam model Machine Learning)
# 2. Scipy : Library fundamental di dalam ekosistem Python untuk komputasi saintifik dan teknis
# 3. wandb : platform experiment tracking untuk Machine Learning, digunakan untuk melacak dan mencatat proses pelatihan model secara real time
# 4. pyECG : Library Python khusus yang digunakan untuk memproses, menganalisis dan mengekstrak fitur - fitur penting dari data sinyal ECG

# %% [markdown]
# PELANGGARAN ETIKA DAN HUKUM PENGGUNAAN AI
#
# CONTOH : Pembuatan konten deepfake untuk penipuan / manipulatif dan pelanggaran Hak Cipta
#
# Etika dan Hukum : menggunakan AI untuk meniru wajah atau suara seseorang tanpa izin untuk menyebarkan hoax telah melanggar etika privasi dan dapat dijerat olah UU ITE terkait manipulasi data elektronik dan penyebaran berita bohong
#
# Hukum hak Cipta : Mengumpulkan Jutaan karya seni, foto atau tulisan miliki kreator dari internet untuk melatih model Machine Learning tanpa memberikan royalti atau meminta izin. Hal ini melanggar hukum kekayaan intelektual
#
# Referensi :
#  Chesney, R., & Citron, D. K. (2019). Deepfakes: A Looming Challenge for Privacy, Democracy, and National Security. California Law Review.
#
# Berita kasus hukum: Gugatan The New York Times terhadap OpenAI (Desember 2023) atas dugaan pelanggaran hak cipta karena menggunakan jutaan artikel mereka untuk melatih ChatGPT.
#
# Dampak Energi & Lingkungan AI dan Cara Mengatasinya
# Jejak Karbon Tinggi: Server dan data center menyedot listrik dalam jumlah raksasa yang mayoritas masih disuplai dari pembangkit listrik berbahan bakar fosil (batu bara).
#
# Krisis Air Bersih: Data center membutuhkan jutaan liter air tawar secara terus-menerus untuk sistem pendingin (cooling system) agar server tidak mengalami overheat.
#
# Cara Mengatasinya
#
# Menerapkan Green AI: Peneliti dan developer tidak seharusnya hanya mengejar akurasi tinggi yang boros parameter, tetapi mulai berfokus pada efisiensi algoritma
#
# Menggunakan Transfer Learning: Sebagai praktisi, kita sebaiknya menggunakan model AI yang sudah dilatih dan hanya melakukan penyesuaian  untuk tugas spesifik, alih-alih melatih model dari nol yang memakan banyak energi.
#
# Infrastruktur Ramah Lingkungan: Mendorong penyedia layanan cloud untuk mengoperasikan data center menggunakan 100% energi terbarukan (surya, angin) dan sistem daur ulang air tertutup (closed-loop cooling).
